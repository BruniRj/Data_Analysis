# %%
def temperature_advice(temp):
    if temp > 30 :
        return "il fait chaud "
    elif temp >= 15 : 
        return "le temps est agreable"
    else :
        return "prend un manteau "

print(temperature_advice(14))
# Out:
# prend un manteau

# %%
# calcul de l'imc 
poid = 10
taille = 1.75
imc = poid / ( taille ** 2 )
if imc < 18.5:
    print("Maigreur")
elif imc < 25:
    print("Normal")
else:
    print("Surpoids")
# Out:
# Maigreur

# %%
# Dataset : notes de 5 étudiants [14, 8, 16, 11, 9]
notes = [14, 8, 16, 11, 9 ]
# 1. Calcule la moyenne
# 2. Affiche combien ont la moyenne (>=10)
# 3. Affiche la meilleure note
# 4. Transforme en dict {"Jean":14, "Sofia":8, ...} (invente prénoms)

# 1 : calcule de la moyenne 
#  somme des valeurs / nombres des valeurs
moyenne = sum(notes) / len(notes)
print(f"voici la moyenne : {moyenne:.2f}")
print(f"voici la moyenne {moyenne}")

# 2 affichage sur combien ont la moyenne 
moyenne_etudiant = 0
for note in notes:
    if note >= 10 : 
        moyenne_etudiant+=1
print(f"voici les etudiants qui ont de la moyenne : {moyenne_etudiant}")

#  meilleur note : 
meilleur = max(notes)
mauvais = min(notes)
print(f"voici l'etudiant ayant la note maximale : {meilleur}  et voici le mauvais {mauvais}")

# transformation du liste en dict
etudiants = ["Jean", "Sofia", "Ali", "Maria", "David"]
notes_dict = dict(zip(etudiants, notes))
print(f"voici les dict par etudiants : {notes_dict}")
# Out:
# voici la moyenne : 11.60
# voici la moyenne 11.6
# voici les etudiants qui ont de la moyenne : 3
# voici l'etudiant ayant la note maximale : 16  et voici le mauvais 8
# voici les dict par etudiants : {'Jean': 14, 'Sofia': 8, 'Ali': 16, 'Maria': 11, 'David': 9}

# %%
# manipulation de donnée avec pandas et numpy 
import pandas as pd 
import numpy as np 
data = {
    "nom":["Charlie", "Bravo", "Alpha" , "Delta"],
    "salaire":[1200, 2000, 2400, 4000],
    "age" : [25,18,24,35]
}
df = pd.DataFrame(data)
print(df[df["salaire"]>1000])
df["prime"] = df["salaire"] * 0.1  # nouvelle colonne
print("voici la nouvelle colonne")
print(df)
# Out:
#        nom  salaire  age
# 0  Charlie     1200   25
# 1    Bravo     2000   18
# 2    Alpha     2400   24
# 3    Delta     4000   35
# voici la nouvelle colonne
#        nom  salaire  age  prime
# 0  Charlie     1200   25  120.0
# 1    Bravo     2000   18  200.0
# 2    Alpha     2400   24  240.0
# 3    Delta     4000   35  400.0
