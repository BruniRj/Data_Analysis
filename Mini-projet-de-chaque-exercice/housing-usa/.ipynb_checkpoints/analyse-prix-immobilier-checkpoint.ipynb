# %%
#  Mini-projet : Dashboard d'analyse des prix immobiliers
# Télécharge "USA Housing Dataset" sur Kaggle.
# Crée une figure avec 3 subplots :

# Distribution des prix (price)

# Nuage de points sqft_living vs price

# Boxplot des prix par nombre de chambres (bedrooms)
